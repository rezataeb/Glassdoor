# %%
#Glassdoor API documentation : https://www.glassdoor.com/developer/index.htm

#import essential libraries

import requests
import json

# authentication and user information 

partner_key = "239219"
partner_id = "dfCHUnSKiuU"
user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/604.3.5 (KHTML, like Gecko) Version/11.0.1 Safari/604.3.5"
user_ip = "198.27.243.149"

# requests parameters
parameters = {
    "v": "1",
    "format": "json",
    "t.p": partner_key ,
    "t.k": partner_id ,
    "action": "employers",
    "employerID" : "11111",
    "userip": user_ip,
    "useragent": user_agent
}

# Glassdoor API endpoint 
url = "http://api.glassdoor.com/api/api.htm"

# request the API
response = requests.get(url, params=parameters, headers={"User-Agent": user_agent})


# Get JSON data
response_data = response.json()
response_data
# Out:
# {'jsessionid': '51C898046B2D6A976B4FF61E84F85DD2',
#  'response': {'attributionURL': 'https://www.glassdoor.com/Reviews/company-reviews.htm',
#   'currentPageNumber': 1,
#   'employers': [{'careerOpportunitiesRating': '3.3',
#     'ceo': {'image': {'height': 200,
#       'src': 'https://media.glassdoor.com/people/sqll/715/walmart-doug-mcmillon.png',
#       'width': 200},
#      'name': 'Doug McMillon',
#      'numberOfRatings': 8904,
#      'pctApprove': 68,
#      'pctDisapprove': 32,
#      'title': 'CEO'},
#     'compensationAndBenefitsRating': '3.2',
#     'cultureAndValuesRating': '3.1',
#     'exactMatch': False,
#     'featuredReview': {'attributionURL': 'https://www.glassdoor.com/Reviews/Employee-Review-Walmart-RVW6773399.htm',
#      'cons': 'Understaffing issues negatively affects all parts of their business. However, Walmart has increased their minimum hourly rate with hopes to attract more committed employees, and retain better employees.',
#      'currentJob': False,
# ...
